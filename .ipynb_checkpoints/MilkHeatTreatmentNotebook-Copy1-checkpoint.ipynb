# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif


# %matplotlib inline

# %% [markdown]
# ## Load milk data into the notebook

# %%
data = pd.read_excel('Milk data for SelectKBest.xlsx', sheetname=0)
data # show the data

# %% [markdown]
# Define the vector of predictors

# %%
predictors = ["Tryptophan", "Mailliard reaction pro", "Vitamin A", "Particle size", "Polydispersity Index"]

# %% [markdown]
# Scale the data to [-1, 1]

# %%
scaler = StandardScaler()
scaler.fit(data[predictors])

data_scaled = scaler.transform(data[predictors])

data_scaled

# %% [markdown]
# What parameters are the most relevant

# %%
selector = SelectKBest(f_classif, k=5)
selector.fit(data[predictors], data["Class"])

scores = -np.log10(selector.pvalues_)

plt.figure(figsize=(15, 10))
plt.bar(range(len(predictors)), scores)
plt.xticks(range(len(predictors)), predictors, rotation='vertical')
plt.show()

# %% [markdown]
# # Rewise the raw data

# %%
raw_data = pd.read_excel('Покупное молоко для matlab _.xlsx', sheetname='tr')

# %% [markdown]
# Form a target column

# %%
raw_data['target'] = (raw_data['class (o)'] == 'positive') * 1

# %% [markdown]
# Form a list of predictors

# %%
raw_predictors = list(raw_data.columns.values)[3:-1]

# %% [markdown]
# Select K best features for classification

# %%
selector = SelectKBest(f_classif, k=5)
selector.fit(raw_data[raw_predictors], raw_data["target"])

scores = -np.log10(selector.pvalues_)

plt.figure(figsize=(15, 10))
plt.bar(range(len(raw_predictors)), scores)
# plt.xticks(range(len(raw_predictors)), raw_predictors, rotation='vertical')
plt.show()

# %% [markdown]
# ## Apply decomposition techniques to the data

# %% [markdown]
# PCA - principal component analysis (http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)

# %%
pca = PCA(n_components=10)
X = pca.fit_transform(raw_data[raw_predictors], raw_data['target'])

plt.figure(figsize=(15, 10))
plt.scatter(X[:, 0], X[:, 1], c = raw_data['target'])

# %%
selector = SelectKBest(f_classif, k=5)
selector.fit(X, raw_data["target"])

scores = -np.log10(selector.pvalues_)

plt.figure(figsize=(15, 10))
plt.bar(range(1, 10 + 1), scores)
# plt.xticks(range(len(raw_predictors)), raw_predictors, rotation='vertical')
plt.show()
